# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import os, os.path
import random
from keras.preprocessing.image import ImageDataGenerator

# %%
img1 = cv2.imread('/data/jpegs_256/v_ApplyEyeMakeup_g05_c01/frame000001.jpg', 0)

# %%
datagen = ImageDataGenerator(rotation_range=20)

# %%
img1_cat = np.concatenate((img1.reshape(*img1.shape,1), img1.reshape(*img1.shape,1)), axis=2)

# %%
img1_cat.shape
# Out:
# (256, 342, 2)

# %%
img_transform = datagen.random_transform(img1_cat)

# %%
plt.imshow(img_transform[:,:,0])

# %%
plt.imshow(img_transform[:,:,1])
